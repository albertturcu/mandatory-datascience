# %%
a = [
        {
            'accuracy': 1,
            'n': 2,
            'd': 3,
            'minS': 4,
            'minL': 5
        }
]

# %%
print(a[0])
# Out:
# {'accuracy': 1, 'n': 2, 'd': 3, 'minS': 4, 'minL': 5}
